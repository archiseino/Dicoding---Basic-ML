# %% [markdown]
# ## Dicoding Data Cleaning Module

# %% [markdown]
# ### Loading the Dataset value
# You can use the pandas library to look up the information about the dataset itself. (Using `dataFrame.info()`)

# %%
### Loading the dataset on the Test and Train dataset
import pandas as pd

train_dataset = pd.read_csv('../house_dataset/train.csv')

## Display the first 5 rows of the dataset
train_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
## Display the info of the dataset
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# ### Dataset Content Analysis
# Way to understand the data characteristic and some properties
# - Data distribution: Look up for the statistic properties value such as mean, median, modus and other to identify the data imbalence / un-normal distribution.
# - Idenfitified Anomaly and Outlier: With analysis, we can identify the outlier that can affect the model performance
# - Understanding the data quality: We can look up for the missing value, duplicated data or inconsistency in dataset.
# - Determining the Data Transformation: We can use some normalization / standarization for transformation for the purpose of the model.

# %%
# Showing Descriptive Dataset Properties
train_dataset.describe(include="all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
#        Alley LotShape LandContour Utilities  ...     PoolArea PoolQC  Fence  \
# count     91     1460        1460      1460  ...  1460.000000      7    281
# unique     2        4           4         2  ...          NaN      3      4
# top     Grvl      Reg         Lvl    AllPub  ...          NaN     Gd  MnPrv
# freq      50      925        1311      1459  ...          NaN      3    157
# mean     NaN      NaN         NaN       NaN  ...     2.758904    NaN    NaN
# std      NaN      NaN         NaN       NaN  ...    40.177307    NaN    NaN
# min      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 25%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 50%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# 75%      NaN      NaN         NaN       NaN  ...     0.000000    NaN    NaN
# max      NaN      NaN         NaN       NaN  ...   738.000000    NaN    NaN
#
#        MiscFeature       MiscVal       MoSold       YrSold  SaleType  \
# count           54   1460.000000  1460.000000  1460.000000      1460
# unique           4           NaN          NaN          NaN         9
# top           Shed           NaN          NaN          NaN        WD
# freq            49           NaN          NaN          NaN      1267
# mean           NaN     43.489041     6.321918  2007.815753       NaN
# std            NaN    496.123024     2.703626     1.328095       NaN
# min            NaN      0.000000     1.000000  2006.000000       NaN
# 25%            NaN      0.000000     5.000000  2007.000000       NaN
# 50%            NaN      0.000000     6.000000  2008.000000       NaN
# 75%            NaN      0.000000     8.000000  2009.000000       NaN
# max            NaN  15500.000000    12.000000  2010.000000       NaN
#
#         SaleCondition      SalePrice
# count            1460    1460.000000
# unique              6            NaN
# top            Normal            NaN
# freq             1198            NaN
# mean              NaN  180921.195890
# std               NaN   79442.502883
# min               NaN   34900.000000
# 25%               NaN  129975.000000
# 50%               NaN  163000.000000
# 75%               NaN  214000.000000
# max               NaN  755000.000000
#
# [11 rows x 81 columns]

# %%
# This part will filter for missing data and return the DataFrame objects
## Second line will doing an element wise operation to show which column that has the missing value.
missing_values = train_dataset.isnull().sum()
missing_values[missing_values > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# ### Handling the Missing Value
# As we can see, we have 1460 rows of data and some of the value has a missing value, so the first thing we can do is to seperate the data has few and more missing value

# %%
## Seperating the dataset train less and over 1000 of missing value
less = missing_values[missing_values < 1000].index
over = missing_values[missing_values >= 1000].index

# %% [markdown]
# ### Filling the Missing Value
# For filling the missing value, firstly  we need to seperate the type of data for the purpose of the filling.

# %%
# Contoh mengisi nilai yang hilang dengan median untuk kolom numerik
numeric_features = train_dataset[less].select_dtypes(include=['number']).columns
train_dataset[numeric_features] = train_dataset[numeric_features].fillna(train_dataset[numeric_features].median())

# %% [markdown]
# ### Notes:
# For number, the way of filling the missing value is by fill it with the median value of that particular column.
#
# For string and object, this get interesting, we have two ways of filling it in.
# - Using modus (most show up data) since it's the better representation in categorical data.
# - Fill it using the new Category (such as `Unknown` or `Missing`)

# %%
### We fill it with the modus data for the missing value of string and object
categorical_features = train_dataset[less].select_dtypes(include=["object"]).columns

## Filling the missing value for each column
for column in categorical_features:
    train_dataset[column] = train_dataset[column].fillna(train_dataset[column].mode()[0])

# %% [markdown]
# If the column with many missing values, we can consider it to remove the column (if the limit is above 75% as the best practice)

# %%
## Remove the column with many missing values
df = train_dataset.drop(columns=over)

# %% [markdown]
# ### Doing verification of the new dat after filetering the missing value
# Since we create a new variable `df` (stands for `DataFrame`). we can show the result

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Handling Outliers
# Outlier is a blocker in a machine learning when there's some error / problem on the data itself.
#
# One way to handle this is using the IQR Method (Interquartile Range). IQR is a distance between the first (Q1) and third (Q3) quartile in a sorted data.
#
# Value outside of this is a outlier.

# %%
### Checking if the dataset has outlier
import seaborn as sns
import matplotlib.pyplot as plt

# for feature in numeric_features:
#     plt.figure(figsize=(10,6))
#     sns.boxplot(x=df[feature])
#     plt.title(f"Box Plot of {feature}")
#     plt.show()

# %% [markdown]
# ### Detection and Removing the Outlier
# We can do several things for this, but firstly we can calcualte the IQR, Q1 and Q3
# - Q1 is the value of the 25th (1/4) value data
# - Q3 is the value of the 75th (3/4) value data
# - IQR is the distance between Q3 and Q1
#
# Lastly we can calculate the Bottom and Upper limit of this
# - Bottom limit = Q1 - 1.5 * IQR
# - Upper limit = Q3 + 1.5 * IQR

# %%
## Simple method for detcting the outliers using IQR
Q1 = df[numeric_features].quantile(0.25)
Q3 = df[numeric_features].quantile(0.75)
IQR = Q3 - Q1

# %%
## Delete the outliers 
condition = ~((df[numeric_features] < (Q1 - 1.5 * IQR)) | (df[numeric_features] > (Q3 + 1.5 * IQR))).any(axis=1)
df_filetered_numeric = df.loc[condition, numeric_features]

## Combining the categorical value
categorical_features = df.select_dtypes(include=["object"]).columns
df = pd.concat([df_filetered_numeric, df.loc[condition, categorical_features]])

# %%
### Checking if the dataset has outlier now
import seaborn as sns
import matplotlib.pyplot as plt

# for feature in numeric_features:
#     plt.figure(figsize=(10,6))
#     sns.boxplot(x=df[feature])
#     plt.title(f"Box Plot of {feature}")
#     plt.show()

# %% [markdown]
# ### Normalization and Standarization Data
#
# Since the data we have for numeric part has different scale, We need to do the normalization / standarication, but here's the diff.
#
# ![image.png](https://dicoding-web-img.sgp1.cdn.digitaloceanspaces.com/original/academy/dos-a3d76eeb567571fdb2f8d40f95b0dff720241015110131.jpeg)
#
# - Normalization (known as the min-max scaling) is to change the feature in some interval (from 0 and 1) usually.
# - Standarization (known as the Z-score scaling) is to change the scale of a feature to have the mean of 0 and standard deviation of 1 of each column (Or we can called it Normal Distribution)
#
# So in the nutshell
# - Normalization: transforms data into the range [0, 1]. Ideal for distance-based models and non-normally distributed data.
# - Standardization: changing the data so that the mean is or approaches 0 and the standard deviation is 1. This helps models that require a normal distribution or data with different scales to be more ideal in the training process.

# %%
## Standarization example
from sklearn.preprocessing import StandardScaler
 
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %% [markdown]
# We can show the diff data comparion before and after scaling.

# %%
## Histogram before standarization
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
## Take the third feature dataset to show
sns.histplot(train_dataset[numeric_features[3]], kde=True)
plt.title("Histogram Sebelum Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram Sebelum Standardisasi')

# %%
## Histogram before standarization
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
## Take the third feature dataset to show
sns.histplot(df[numeric_features[3]], kde=True)
plt.title("Histogram Sebelum Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram Sebelum Standardisasi')

# %% [markdown]
# ### Handling Data Duplication
# The journey is not over yet, we still need to handle for duplicate data mate.

# %%
# Mengidentifikasi baris duplikat
duplicates = df.duplicated()
 
print("Duplicated:")
print(df[duplicates])
# Out:
# Duplicated:
#       Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 590  NaN         NaN          NaN      NaN          NaN          NaN
# 616  NaN         NaN          NaN      NaN          NaN          NaN
# 721  NaN         NaN          NaN      NaN          NaN          NaN
# 824  NaN         NaN          NaN      NaN          NaN          NaN
# 850  NaN         NaN          NaN      NaN          NaN          NaN
# 851  NaN         NaN          NaN      NaN          NaN          NaN
# 933  NaN         NaN          NaN      NaN          NaN          NaN
# 999  NaN         NaN          NaN      NaN          NaN          NaN
# 1004 NaN         NaN          NaN      NaN          NaN          NaN
# 1133 NaN         NaN          NaN      NaN          NaN          NaN
# 1188 NaN         NaN          NaN      NaN          NaN          NaN
# 1198 NaN         NaN          NaN      NaN          NaN          NaN
# 1207 NaN         NaN          NaN      NaN          NaN          NaN
# 1240 NaN         NaN          NaN      NaN          NaN          NaN
# 1306 NaN         NaN          NaN      NaN          NaN          NaN
# 1311 NaN         NaN          NaN      NaN          NaN          NaN
# 1342 NaN         NaN          NaN      NaN          NaN          NaN
# 1368 NaN         NaN          NaN      NaN          NaN          NaN
# 1390 NaN         NaN          NaN      NaN          NaN          NaN
# 1410 NaN         NaN          NaN      NaN          NaN          NaN
# 1422 NaN         NaN          NaN      NaN          NaN          NaN
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  \
# 590         NaN           NaN         NaN         NaN  ...           Gd
# 616         NaN           NaN         NaN         NaN  ...           Gd
# 721         NaN           NaN         NaN         NaN  ...           Gd
# 824         NaN           NaN         NaN         NaN  ...           Gd
# 850         NaN           NaN         NaN         NaN  ...           Gd
# 851         NaN           NaN         NaN         NaN  ...           Gd
# 933         NaN           NaN         NaN         NaN  ...           Gd
# 999         NaN           NaN         NaN         NaN  ...           Gd
# 1004        NaN           NaN         NaN         NaN  ...           Gd
# 1133        NaN           NaN         NaN         NaN  ...           Gd
# 1188        NaN           NaN         NaN         NaN  ...           Gd
# 1198        NaN           NaN         NaN         NaN  ...           Gd
# 1207        NaN           NaN         NaN         NaN  ...           Gd
# 1240        NaN           NaN         NaN         NaN  ...           Gd
# 1306        NaN           NaN         NaN         NaN  ...           Gd
# 1311        NaN           NaN         NaN         NaN  ...           Gd
# 1342        NaN           NaN         NaN         NaN  ...           Gd
# 1368        NaN           NaN         NaN         NaN  ...           Gd
# 1390        NaN           NaN         NaN         NaN  ...           Gd
# 1410        NaN           NaN         NaN         NaN  ...           Gd
# 1422        NaN           NaN         NaN         NaN  ...           Gd
#
#       Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 590          Typ           Gd      Attchd           RFn          TA
# 616          Typ           Gd      Attchd           Fin          TA
# 721          Typ           Gd      Attchd           RFn          TA
# 824          Typ           Gd      Attchd           RFn          TA
# 850          Typ           Gd      Attchd           Fin          TA
# 851          Typ           TA      Attchd           Fin          TA
# 933          Typ           Gd      Attchd           RFn          TA
# 999          Typ           Gd      Attchd           RFn          TA
# 1004         Typ           Gd      Attchd           Fin          TA
# 1133         Typ           TA      Attchd           RFn          TA
# 1188         Typ           Gd      Attchd           RFn          TA
# 1198         Typ           Gd      Attchd           RFn          TA
# 1207         Typ           Gd      Attchd           RFn          TA
# 1240         Typ           Gd      Attchd           RFn          TA
# 1306         Typ           Gd      Attchd           RFn          TA
# 1311         Typ           Gd      Attchd           RFn          TA
# 1342         Typ           Gd      Attchd           RFn          TA
# 1368         Typ           Gd      Attchd           Fin          TA
# 1390         Typ           Gd      Attchd           RFn          TA
# 1410         Typ           Gd      Attchd           RFn          TA
# 1422         Typ           Gd      Attchd           Fin          TA
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 590           TA           Y        WD         Normal
# 616           TA           Y        WD         Normal
# 721           TA           Y        WD         Normal
# 824           TA           Y       New        Partial
# 850           TA           Y        WD         Normal
# 851           TA           Y        WD         Normal
# 933           TA           Y        WD         Normal
# 999           TA           Y        WD         Normal
# 1004          TA           Y        WD         Normal
# 1133          TA           Y        WD         Normal
# 1188          TA           Y        WD         Normal
# 1198          TA           Y        WD         Normal
# 1207          TA           Y        WD         Normal
# 1240          TA           Y        WD         Normal
# 1306          TA           Y       New        Partial
# 1311          TA           Y       New        Partial
# 1342          TA           Y        WD         Normal
# 1368          TA           Y        WD         Normal
# 1390          TA           Y        WD         Normal
# 1410          TA           Y        WD         Normal
# 1422          TA           Y        WD         Normal
#
# [21 rows x 77 columns]

# %% [markdown]
# Well, we've got many duplicated data, we can delete this (I don't know it supposed to be deleted the NaN values in the missing value stuff), but I guess I missed it, so yeah just delete it.

# %%
## Drop th Duplcate missing value
df = df.drop_duplicates()

## Show the duplicate
duplicates = df.duplicated()
 
print("Duplicated:")
print(df[duplicates])
df
# Out:
# Duplicated:
# Empty DataFrame
# Columns: [Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SalePrice, MSZoning, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, Heating, HeatingQC, CentralAir, Electrical, KitchenQual, Functional, FireplaceQu, GarageType, GarageFinish, GarageQual, GarageCond, PavedDrive, SaleType, SaleCondition]
# Index: []
#
# [0 rows x 77 columns]
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0    -1.768952    0.356986    -0.265012 -0.284244     0.614520    -0.523677
# 2    -1.764179    0.356986    -0.037099  0.744924     0.614520    -0.523677
# 4    -1.759405    0.356986     1.178437  1.851281     1.419903    -0.523677
# 6    -1.754632   -0.917637     0.494698  0.316349     1.419903    -0.523677
# 10   -1.745085   -0.917637     0.114843  0.726546    -0.996245    -0.523677
# ...        ...         ...          ...       ...          ...          ...
# 1448       NaN         NaN          NaN       NaN          NaN          NaN
# 1451       NaN         NaN          NaN       NaN          NaN          NaN
# 1453       NaN         NaN          NaN       NaN          NaN          NaN
# 1454       NaN         NaN          NaN       NaN          NaN          NaN
# 1455       NaN         NaN          NaN       NaN          NaN          NaN
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  \
# 0      0.784193      0.704506    1.183911    0.639427  ...          NaN
# 2      0.704296      0.653431    0.856804    0.101006  ...          NaN
# 4      0.664347      0.551281    2.665515    0.514611  ...          NaN
# 6      0.824141      0.806656    1.087703    2.262035  ...          NaN
# 10    -0.733845     -1.236347   -0.701766    1.128902  ...          NaN
# ...         ...           ...         ...         ...  ...          ...
# 1448        NaN           NaN         NaN         NaN  ...           TA
# 1451        NaN           NaN         NaN         NaN  ...           Ex
# 1453        NaN           NaN         NaN         NaN  ...           TA
# 1454        NaN           NaN         NaN         NaN  ...           Gd
# 1455        NaN           NaN         NaN         NaN  ...           TA
#
#       Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 0            NaN          NaN         NaN           NaN         NaN
# 2            NaN          NaN         NaN           NaN         NaN
# 4            NaN          NaN         NaN           NaN         NaN
# 6            NaN          NaN         NaN           NaN         NaN
# 10           NaN          NaN         NaN           NaN         NaN
# ...          ...          ...         ...           ...         ...
# 1448        Min2           Gd      Detchd           Unf          Fa
# 1451         Typ           Gd      Attchd           Fin          TA
# 1453         Typ           Gd      Attchd           Unf          TA
# 1454         Typ           Gd      Attchd           RFn          TA
# 1455         Typ           TA      Attchd           RFn          TA
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 0            NaN         NaN       NaN            NaN
# 2            NaN         NaN       NaN            NaN
# 4            NaN         NaN       NaN            NaN
# 6            NaN         NaN       NaN            NaN
# 10           NaN         NaN       NaN            NaN
# ...          ...         ...       ...            ...
# 1448          TA           Y        WD         Normal
# 1451          TA           Y       New        Partial
# 1453          TA           Y        WD        Abnorml
# 1454          TA           Y        WD         Normal
# 1455          TA           Y        WD         Normal
#
# [1093 rows x 77 columns]

# %% [markdown]
# ### Data types Convertion
# Since the ML Model basically just matrix multiplication and layering stuff that takes and numeric input, it can be a problem for categorical one.
#
# To handle convertion from the categorical and numeric, we can use something that called the Encoding. There's some examples of them
# - One-Hot Encoding: Changing the Every category into binary column with (0 and 1)
# - Label Encoding: Giving a label for each category, even though it only works for small set of category data
# - Ordinal Encoding: Mapping Convertion from each category into numeric value.

# %%
### Getting the dataset value
category_features = df.select_dtypes(include=["object"]).columns
df[category_features]
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0         NaN    NaN      NaN         NaN       NaN       NaN       NaN
# 2         NaN    NaN      NaN         NaN       NaN       NaN       NaN
# 4         NaN    NaN      NaN         NaN       NaN       NaN       NaN
# 6         NaN    NaN      NaN         NaN       NaN       NaN       NaN
# 10        NaN    NaN      NaN         NaN       NaN       NaN       NaN
# ...       ...    ...      ...         ...       ...       ...       ...
# 1448       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1451       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1453       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1454       FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... KitchenQual Functional  \
# 0             NaN        NaN        NaN  ...         NaN        NaN
# 2             NaN        NaN        NaN  ...         NaN        NaN
# 4             NaN        NaN        NaN  ...         NaN        NaN
# 6             NaN        NaN        NaN  ...         NaN        NaN
# 10            NaN        NaN        NaN  ...         NaN        NaN
# ...           ...        ...        ...  ...         ...        ...
# 1448      Edwards       Norm       Norm  ...          TA       Min2
# 1451      Somerst       Norm       Norm  ...          Ex        Typ
# 1453      Mitchel       Norm       Norm  ...          TA        Typ
# 1454      Somerst       Norm       Norm  ...          Gd        Typ
# 1455      Gilbert       Norm       Norm  ...          TA        Typ
#
#      FireplaceQu GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# 0            NaN        NaN          NaN        NaN        NaN        NaN
# 2            NaN        NaN          NaN        NaN        NaN        NaN
# 4            NaN        NaN          NaN        NaN        NaN        NaN
# 6            NaN        NaN          NaN        NaN        NaN        NaN
# 10           NaN        NaN          NaN        NaN        NaN        NaN
# ...          ...        ...          ...        ...        ...        ...
# 1448          Gd     Detchd          Unf         Fa         TA          Y
# 1451          Gd     Attchd          Fin         TA         TA          Y
# 1453          Gd     Attchd          Unf         TA         TA          Y
# 1454          Gd     Attchd          RFn         TA         TA          Y
# 1455          TA     Attchd          RFn         TA         TA          Y
#
#      SaleType SaleCondition
# 0         NaN           NaN
# 2         NaN           NaN
# 4         NaN           NaN
# 6         NaN           NaN
# 10        NaN           NaN
# ...       ...           ...
# 1448       WD        Normal
# 1451      New       Partial
# 1453       WD       Abnorml
# 1454       WD        Normal
# 1455       WD        Normal
#
# [1093 rows x 39 columns]

# %%
## Doing one-hot encoding
df_one_hot = pd.get_dummies(df, columns=category_features)
df_one_hot
# Out:
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0    -1.768952    0.356986    -0.265012 -0.284244     0.614520    -0.523677
# 2    -1.764179    0.356986    -0.037099  0.744924     0.614520    -0.523677
# 4    -1.759405    0.356986     1.178437  1.851281     1.419903    -0.523677
# 6    -1.754632   -0.917637     0.494698  0.316349     1.419903    -0.523677
# 10   -1.745085   -0.917637     0.114843  0.726546    -0.996245    -0.523677
# ...        ...         ...          ...       ...          ...          ...
# 1448       NaN         NaN          NaN       NaN          NaN          NaN
# 1451       NaN         NaN          NaN       NaN          NaN          NaN
# 1453       NaN         NaN          NaN       NaN          NaN          NaN
# 1454       NaN         NaN          NaN       NaN          NaN          NaN
# 1455       NaN         NaN          NaN       NaN          NaN          NaN
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# 0      0.784193      0.704506    1.183911    0.639427  ...           False
# 2      0.704296      0.653431    0.856804    0.101006  ...           False
# 4      0.664347      0.551281    2.665515    0.514611  ...           False
# 6      0.824141      0.806656    1.087703    2.262035  ...           False
# 10    -0.733845     -1.236347   -0.701766    1.128902  ...           False
# ...         ...           ...         ...         ...  ...             ...
# 1448        NaN           NaN         NaN         NaN  ...           False
# 1451        NaN           NaN         NaN         NaN  ...           False
# 1453        NaN           NaN         NaN         NaN  ...           False
# 1454        NaN           NaN         NaN         NaN  ...           False
# 1455        NaN           NaN         NaN         NaN  ...           False
#
#       SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0              False         False         False        False
# 2              False         False         False        False
# 4              False         False         False        False
# 6              False         False         False        False
# 10             False         False         False        False
# ...              ...           ...           ...          ...
# 1448           False         False         False         True
# 1451           False          True         False        False
# 1453           False         False         False         True
# 1454           False         False         False         True
# 1455           False         False         False         True
#
#       SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Family  \
# 0                     False                  False                 False
# 2                     False                  False                 False
# 4                     False                  False                 False
# 6                     False                  False                 False
# 10                    False                  False                 False
# ...                     ...                    ...                   ...
# 1448                  False                  False                 False
# 1451                  False                  False                 False
# 1453                   True                  False                 False
# 1454                  False                  False                 False
# 1455                  False                  False                 False
#
#       SaleCondition_Normal  SaleCondition_Partial
# 0                    False                  False
# 2                    False                  False
# 4                    False                  False
# 6                    False                  False
# 10                   False                  False
# ...                    ...                    ...
# 1448                  True                  False
# 1451                 False                   True
# 1453                 False                  False
# 1454                  True                  False
# 1455                  True                  False
#
# [1093 rows x 216 columns]

# %%
## Label Encoding
from sklearn.preprocessing import LabelEncoder
 
# Inisialisasi LabelEncoder
label_encoder = LabelEncoder()
df_lencoder = pd.DataFrame(df)
 
for col in category_features:
    df_lencoder[col] = label_encoder.fit_transform(df[col])
 
# Menampilkan hasil
df_lencoder
# Out:
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0    -1.768952    0.356986    -0.265012 -0.284244     0.614520    -0.523677
# 2    -1.764179    0.356986    -0.037099  0.744924     0.614520    -0.523677
# 4    -1.759405    0.356986     1.178437  1.851281     1.419903    -0.523677
# 6    -1.754632   -0.917637     0.494698  0.316349     1.419903    -0.523677
# 10   -1.745085   -0.917637     0.114843  0.726546    -0.996245    -0.523677
# ...        ...         ...          ...       ...          ...          ...
# 1448       NaN         NaN          NaN       NaN          NaN          NaN
# 1451       NaN         NaN          NaN       NaN          NaN          NaN
# 1453       NaN         NaN          NaN       NaN          NaN          NaN
# 1454       NaN         NaN          NaN       NaN          NaN          NaN
# 1455       NaN         NaN          NaN       NaN          NaN          NaN
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  \
# 0      0.784193      0.704506    1.183911    0.639427  ...            4
# 2      0.704296      0.653431    0.856804    0.101006  ...            4
# 4      0.664347      0.551281    2.665515    0.514611  ...            4
# 6      0.824141      0.806656    1.087703    2.262035  ...            4
# 10    -0.733845     -1.236347   -0.701766    1.128902  ...            4
# ...         ...           ...         ...         ...  ...          ...
# 1448        NaN           NaN         NaN         NaN  ...            3
# 1451        NaN           NaN         NaN         NaN  ...            0
# 1453        NaN           NaN         NaN         NaN  ...            3
# 1454        NaN           NaN         NaN         NaN  ...            2
# 1455        NaN           NaN         NaN         NaN  ...            3
#
#       Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 0              5            5           4             3           3
# 2              5            5           4             3           3
# 4              5            5           4             3           3
# 6              5            5           4             3           3
# 10             5            5           4             3           3
# ...          ...          ...         ...           ...         ...
# 1448           3            2           3             2           0
# 1451           4            2           0             0           2
# 1453           4            2           0             2           2
# 1454           4            2           0             1           2
# 1455           4            4           0             1           2
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 0              4           3         9              5
# 2              4           3         9              5
# 4              4           3         9              5
# 6              4           3         9              5
# 10             4           3         9              5
# ...          ...         ...       ...            ...
# 1448           3           2         8              3
# 1451           3           2         6              4
# 1453           3           2         8              0
# 1454           3           2         8              3
# 1455           3           2         8              3
#
# [1093 rows x 77 columns]
